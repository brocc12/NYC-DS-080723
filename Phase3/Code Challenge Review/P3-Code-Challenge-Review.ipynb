# %% [markdown]
# # Phase 3 Code Challenge Review
#
# Made using resources from the Seattle team - thanks y'all.

# %% [markdown]
# ## Overview
#
# * Gradient Descent
# * Logistic Regression
# * Classification Metrics
# * Decision Trees

# %%
# Imports
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import roc_curve, auc

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_curve,RocCurveDisplay

# %%
# from src.call import call_on_students

# %% [markdown]
# ## Part 1: Gradient Descent

# %% [markdown]
# ### Set Up

# %%
# Grab the data from 'auto-mpg.csv'
mpg_df = pd.read_csv("data/auto-mpg.csv")

# %%
# Explore the data
mpg_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
# Let's plot a simple linear regression line using just the horsepower column
plt.figure(figsize=(8, 6))
sns.regplot(x='horsepower', y='mpg', data=mpg_df, line_kws={"color":"orange"})
plt.title('Relationship Between Horsepower and MPG')
plt.xlim(0, 250)
plt.show()

# %% [markdown]
# The above graph shows an approximate best fit line for the relationship between `horsepower` and `mpg` in our data.

# %% [markdown]
# ### 1) Describe the below chart: What is it showing? What does it tell us?
#
# ![Slope-RSS relationship image](images/slope-rss-relationship.png)

# %% [markdown]
# # call_on_students(1)
# this is a simple cost function with a minimun around -0.155 < x < -0.160

# %% [markdown]
# #### Answer:
#
# -

# %% [markdown]
# ### 2) Imagine that you're starting at a slope towards the top upper left corner. Using Zoom's annotate feature, demonstrate how gradient descent would work

# %% [markdown]
# # call_on_students(1)
#
# gradient decent would call upon the learning rate to determine the size of the step to take, accounting for the size of step and new value, the gradient is determined, these steps ar repeated until the value is close to zero, or has finished the predtermined set of steps

# %% [markdown]
# ### 3) What is a step size when talking about gradient descent? How does learning rate regulate step size?

# %% [markdown]
# # call_on_students(1)
#
# step size is the amount down the gradient you go, and it is regulated by slope size by giving it a max number to work with.  it's essential to choose an appropriate learning rate to balance convergence speed and stability.

# %% [markdown]
# #### Answer:
#
# -

# %% [markdown]
# ## Part 2: Logistic Regression

# %% [markdown]
# ### 4) Describe a logistic regression model:
#
# - What kind of target is a logistic regression model used for?
# - What are the predictions that a logistic regression model outputs?
# - How is it different from linear regression?
# - Is it a parametric or non-parametric model?

# %% [markdown]
# a logistic regression model is used with categorical values and returns a prediction as a number between 0 and 1. In linear regression, the output is a linear combination of predictor variables, and the predicted values can be any number. In contrast, logistic regression uses a function to map the linear combination of predictors to a probability score. logistical regression is a paametric model

# %% [markdown]
# #### Answer:
#
# -

# %% [markdown]
# ### 5) Compare a logistic regression model to any of the other model types we've learned:
#
# - List one benefit of logistic regression when compared to the other model type
# - List one reason the other model type might be more useful

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# -

# %% [markdown]
# ## Part 3: Logistic Regression and Classification Metrics with Code
#
# ### Set Up

# %%
# Let's use the same data, but now with a classification target
mpg_class = pd.read_csv('data/auto-mpg-classification.csv')

# %%
# Check this new dataframe out
mpg_class.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0          8         307.0         130    3504          12.0          70
# 1          8         350.0         165    3693          11.5          70
# 2          8         318.0         150    3436          11.0          70
# 3          8         304.0         150    3433          12.0          70
# 4          8         302.0         140    3449          10.5          70
#
#    origin  target
# 0       1       0
# 1       1       1
# 2       1       0
# 3       1       1
# 4       1       1

# %% [markdown]
# ### 6) Prepare our data for modeling:
#
# 1. Perform a train/test split
# 2. Scale the inputs

# %%
# call_on_students(1)

# %%
# Train-test split
X = mpg_class.drop("target", axis=1)  # Features (all columns except "target")
y = mpg_class["target"]  # Target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Step 2: Scale the inputs (standardization in this case)
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and testing data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Set test_size=0.33 and random_state=42

# %%
# Scale the dat
X
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0            8         307.0         130    3504          12.0          70
# 1            8         350.0         165    3693          11.5          70
# 2            8         318.0         150    3436          11.0          70
# 3            8         304.0         150    3433          12.0          70
# 4            8         302.0         140    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 387          4         140.0          86    2790          15.6          82
# 388          4          97.0          52    2130          24.6          82
# 389          4         135.0          84    2295          11.6          82
# 390          4         120.0          79    2625          18.6          82
# 391          4         119.0          82    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %% [markdown]
# ### 7) Explore the `target` column and our model-less baseline
#
# 1. What is the breakdown of the `target` column in our training data?
# 2. What would a model-less baseline look like in this context?
# 3. How accurate would that model-less understanding be on our test data?

# %%
# call_on_students(1)

# %% [markdown]
# #### Part 1: explore the target column breakdown in train data

# %%
# Code to explore

# %% [markdown]
# #### Answer:
#
# -

# %% [markdown]
# #### Part 2: What would a model-less baseline look like in this context?
#
# #### Answer:
#
# -

# %% [markdown]
# #### Part 3: How accurate would that baseline be on test data?

# %%
# Code to find the answer

# %% [markdown]
# #### Answer:
#
# -

# %% [markdown]
# ### 8) What is one problem you could foresee based on this breakdown, and what is one strategy you could employ to address that problem?

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# -

# %% [markdown]
# ### 9) Fit a logistic regression model, and plot a confusion matrix of the results on our test set

# %%
# call_on_students(1)

# %%
# Fit a logistic regression model
# Name the model `logreg` and set random_state = 42
logreg = LogisticRegression(random_state=42)
logreg.fit(X_train_scaled, y_train)

y_pred = logreg.predict(X_test_scaled)
conf_matrix = confusion_matrix(y_test, y_pred)
conf_matrix
# Out:
# array([[97,  1],
#        [ 9, 23]], dtype=int64)

# %%
# Plot a confusion matrix on the test data
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix, cmap='Blues', interpolation='nearest')
plt.title('Confusion Matrix')
plt.colorbar()
plt.xticks([0, 1], ['Predicted 0', 'Predicted 1'])
plt.yticks([0, 1], ['Actual 0', 'Actual 1'])
# Out:
# ([<matplotlib.axis.YTick at 0x1e1b9388810>,
# ...
#  [Text(0, 0, 'Actual 0'), Text(0, 1, 'Actual 1')])

# %% [markdown]
# ### 10) Calculate the accuracy, precision, recall and f1-score for the test set
#
# You can use the confusion matrix above, or sklearn functions

# %%
# call_on_students(1)
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1-score
f1 = f1_score(y_test, y_pred)

# %%
# Accuracy
accuracy
# Out:
# 0.9230769230769231

# %%
# Precision
precision
# Out:
# 0.9583333333333334

# %%
# Recall
recall
# Out:
# 0.71875

# %%
# F1-Score
f1
# Out:
# 0.8214285714285714

# %% [markdown]
# ### 11) Calculate the ROC-AUC on the test set, and plot the ROC curve
#
# For this you'll definitely want to use the sklearn functions!

# %%
# call_on_students(1)

# %%
# Calculate roc-auc
roc_auc = roc_auc_score(y_test, logreg.predict_proba(X_test_scaled)[:, 1])
roc_auc
# Out:
# 0.9811862244897959

# %%
print('AUC: {}'.format(auc(fpr, tpr)))
# Out:
# AUC: 0.982780612244898

# %%
# Plot the ROC curve
y_score = logreg.fit(X_train, y_train).decision_function(X_test)

fpr, tpr, thresholds = roc_curve(y_test, y_score)
# %matplotlib inline

# Seaborn's beautiful styling
sns.set_style('darkgrid', {'axes.facecolor': '0.9'})

plt.figure(figsize=(10, 8))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve')
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/20.0 for i in range(21)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# C:\Users\beast\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### 12) Evaluate! Based on the metrics of our test data, how is our model doing?

# %% [markdown]
# # call_on_students(1)
#
# our model is doing very well as demonstarted by the high and to the top left graph

# %% [markdown]
# #### Answer:
#
# -

# %% [markdown]
# ## Part 4: Decision Trees
#
# ### Set Up - Generating 1-split trees to compare

# %%
# Creating two different decision trees with a single split
dt_maxdepth1_v1 = DecisionTreeClassifier(max_depth=1, random_state = 42)
dt_maxdepth1_v2 = DecisionTreeClassifier(max_depth=1, random_state = 42)

# Training the two trees on different columns
dt_maxdepth1_v1.fit(X_train[['weight']], y_train)
dt_maxdepth1_v2.fit(X_train[['origin']], y_train)
# Out:
# DecisionTreeClassifier(max_depth=1, random_state=42)

# %%
# Tree based on 1st column
plot_tree(dt_maxdepth1_v1, feature_names=['weight'], filled=True);

# %%
# Tree based on 2nd column
plot_tree(dt_maxdepth1_v2, feature_names=['origin'], filled=True);

# %% [markdown]
# #### Result:
#
# (showing the image output incase there is a problem with the above code to generate and visualize these trees)
#
# | Version 1: Weight | Version 2: Origin |
# | ----------------- | ----------------- |
# | ![max depth 1 - version 1](images/dt-maxdepth1-v1.png) | ![max depth 1 - version 2](images/dt-maxdepth1-v2.png) |

# %% [markdown]
# ### 13) Which of these trees does a better job splitting the data? How can you tell?

# %% [markdown]
# # call_on_students(1)
#
# the gini measures were far better on the lft tree so i can pick that as the higher performing decision tree

# %% [markdown]
# #### Answer:
#
# -

# %% [markdown]
# ### 14) Fit a decision tree model, and plot a confusion matrix of the results on our test set

# %%
# call_on_students(1)

# %%
# Fit a decision tree model
# Name the model `dt` and set random_state = 42
dt = DecisionTreeClassifier(random_state = 42)
dt.fit(X_train_scaled, y_train)

y_pred = dt.predict(X_test_scaled)

# %%
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix2, cmap='Blues', interpolation='nearest')
plt.title('Confusion Matrix')
plt.colorbar()
plt.xticks([0, 1], ['Predicted 0', 'Predicted 1'])
plt.yticks([0, 1], ['Actual 0', 'Actual 1'])
# Out:
# ([<matplotlib.axis.YTick at 0x1e1bb8e4c90>,
# ...
#  [Text(0, 0, 'Actual 0'), Text(0, 1, 'Actual 1')])

# %%
ConfusionMatrixDisplay.from_estimator(dt, X_test_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 ConfusionMatrixDisplay.from_estimator(dt, X_test_scaled, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py:322, in ConfusionMatrixDisplay.from_estimator(cls, estimator, X, y, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax, colorbar, im_kw, text_kw)
#     319     raise ValueError(f"{method_name} only supports classifiers")
#     320 y_pred = estimator.predict(X)
# --> 322 return cls.from_predictions(
#     323     y,
#     324     y_pred,
#     325     sample_weight=sample_weight,
#     326     labels=labels,
#     327     normalize=normalize,
#     328     display_labels=display_labels,
#     329     include_values=include_values,
#     330     cmap=cmap,
#     331     ax=ax,
# ...

# %%
# Plot a confusion matrix on the test data
conf_matrix2 = confusion_matrix(y_test, y_pred)
conf_matrix2
# Out:
# array([[95,  3],
#        [ 8, 24]], dtype=int64)

# %%
# Code to visualize the ROC curves for the models we've done
fig, ax = plt.subplots()
plot_roc_curve(dt, X_test_scaled, y_test, ax=ax)
plot_roc_curve(logreg, X_test_scaled, y_test, ax=ax)

plt.title("Receiver Operating Characteristic Curves\n(Evaluated on Test Set)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 3
#       1 # Code to visualize the ROC curves for the models we've done
#       2 fig, ax = plt.subplots()
# ----> 3 plot_roc_curve(dt, X_test_scaled, y_test, ax=ax)
#       4 plot_roc_curve(logreg, X_test_scaled, y_test, ax=ax)
#       6 plt.title("Receiver Operating Characteristic Curves\n(Evaluated on Test Set)")
#
# NameError: name 'plot_roc_curve' is not defined

# %% [markdown]
# ### 15) Which is the better model according to ROC-AUC score? How can you tell?

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# -
